# %%
import pandas as pd
import pandas as pd
import seaborn as sns
data = "https://gist.githubusercontent.com/meperezcuello/82a9f1c1c473d6585e750ad2e3c05a41/raw/d42d226d0dd64e7f5395a0eec1b9190a10edbc03/Medical_Cost.csv"
df = pd.read_csv(data)
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ***The following analysis will attempt to answer four research questions.Is there a correlation between BMI and age? The number of children and charges? Is there a region with a greater average age that also results in higher average charges? What is the most dominant variable in determining the costs of insurance charges?***

# %% [markdown]
# ---

# %% [markdown]
# **Finiding a BMI / Age Correlation:**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = "https://gist.githubusercontent.com/meperezcuello/82a9f1c1c473d6585e750ad2e3c05a41/raw/d42d226d0dd64e7f5395a0eec1b9190a10edbc03/Medical_Cost.csv"
df = pd.read_csv(data)
df.groupby(by=["age"]).mean()
sns.lmplot(x="age", y="bmi", data=df)

# %% [markdown]
# *As demonstrated by the visulaization above the BMI remains constant for all ages .Thus , we cannot conclude a correlation betweeb BMI and age.*

# %% [markdown]
# ---

# %% [markdown]
# **Finding a correlation between the number of children and the average charge:**

# %%
df.groupby(by=["children"]).mean()
# Out:
#                 age        bmi       charges
# children
# 0         38.444251  30.550296  12365.975602
# 1         39.453704  30.623148  12731.171832
# 2         39.445833  30.978104  15073.563734
# 3         41.566879  30.684331  15355.318367
# 4         39.000000  31.391200  13850.656311
# 5         35.611111  29.605000   8786.035247

# %%
sns.barplot(x="children", y="charges", data=df)
# Out:
# <AxesSubplot:xlabel='children', ylabel='charges'>

# %% [markdown]
# *Demonstrated by the data and visualization above we can see that indivivuals with 0,1,and 4 childern have close average charge of around 12500. The charges of of individuals with 2 and 3 childeren are significantly higher at around 15000. Finally, individuals with 5 children have a lower average charge of around 8000. While a certain number of children correlates with a higher or lower charge , it is not linear in the sense that less childern result in less charges or more childern result in more charges.*

# %% [markdown]
# ---

# %%
dfbar=df.groupby(by=["region"]).mean()
dfbar
# Out:
#                  age        bmi  children       charges
# region
# northeast  39.268519  29.173503  1.046296  13406.384516
# northwest  39.196923  29.199785  1.147692  12417.575374
# southeast  38.939560  33.355989  1.049451  14735.411438
# southwest  39.455385  30.596615  1.141538  12346.937377

# %%
sns.barplot(x="region", y="charges", data=df)
# Out:
# <AxesSubplot:xlabel='region', ylabel='charges'>

# %% [markdown]
# *Seeing as the the four regions have a close average age and charges, we cannot conclude a correlation between a particular region with a higher average age and a higher charge.*

# %% [markdown]
# ---

# %%
dfplot=df.groupby(by=["age"]).mean()
dfplot
# Out:
#            bmi  children       charges
# age
# 18   31.326159  0.449275   7086.217556
# 19   28.596912  0.426471   9747.909335
# 20   30.632759  0.862069  10159.697736
# 21   28.185714  0.785714   4730.464330
# 22   31.087679  0.714286  10012.932802
# 23   31.454464  1.000000  12419.820040
# 24   29.142679  0.464286  10648.015962
# 25   29.693929  1.285714   9838.365311
# 26   29.428929  1.071429   6133.825309
# 27   29.333571  0.964286  12184.701721
# 28   29.482143  1.285714   9069.187564
# 29   29.383148  1.259259  10430.158727
# 30   30.557593  1.555556  12719.110358
# 31   29.918333  1.407407  10196.980573
# 32   31.597692  1.269231   9220.300291
# 33   31.163077  1.538462  12351.532987
# 34   30.274038  1.153846  11613.528121
# 35   31.394800  1.680000  11307.182031
# 36   29.374200  1.240000  12204.476138
# 37   31.216600  1.520000  18019.911877
# 38   28.996600  1.480000   8102.733674
# 39   29.910200  2.200000  11778.242945
# 40   30.139074  1.592593  11772.251310
# ...

# %%
sns.lineplot(x="age", y="charges",data=dfplot)
# Out:
# <AxesSubplot:xlabel='age', ylabel='charges'>

# %% [markdown]
# *As demonstrated in the lineplot above we can see a correlation between an older age and higher charges.*

# %% [markdown]
# ---

# %% [markdown]
# **After a thorough analysis we can conclude that age is the most reliable variable that directly correlates with higher charges.**
