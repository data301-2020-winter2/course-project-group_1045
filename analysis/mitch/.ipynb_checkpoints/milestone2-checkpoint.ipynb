# %%
import pandas as pd
import numpy as np
import os
import sys
import matplotlib.pylab as plt
import seaborn as sns

url = "https://gist.githubusercontent.com/meperezcuello/82a9f1c1c473d6585e750ad2e3c05a41/raw/d42d226d0dd64e7f5395a0eec1b9190a10edbc03/Medical_Cost.csv"

# %%
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from scripts import project_functions
df = project_functions.load_and_process(url)
df.head(10)
# Out:
#    Age     Sex   BMI  Children Smoker     Region  Charges       Body Shape
# 0   54  Female  47.4         0    Yes  Southeast    63770  Class 3 Obesity
# 1   45    Male  30.4         0    Yes  Southeast    62592  Class 1 Obesity
# 2   52    Male  34.5         3    Yes  Northwest    60021  Class 2 Obesity
# 3   31  Female  38.1         1    Yes  Northeast    58571  Class 3 Obesity
# 4   33  Female  35.5         0    Yes  Northwest    55135  Class 2 Obesity
# 5   60    Male  32.8         0    Yes  Southwest    52590  Class 2 Obesity
# 6   28    Male  36.4         1    Yes  Southwest    51194  Class 2 Obesity
# 7   64    Male  37.0         2    Yes  Southeast    49577  Class 2 Obesity
# 8   59    Male  41.1         1    Yes  Southeast    48970  Class 3 Obesity
# 9   44  Female  38.1         0    Yes  Southeast    48885  Class 3 Obesity

# %%
df.shape
# Out:
# (1338, 8)

# %%
df.head()
# Out:
#    Age     Sex   BMI  Children Smoker     Region  Charges       Body Shape
# 0   54  Female  47.4         0    Yes  Southeast    63770  Class 3 Obesity
# 1   45    Male  30.4         0    Yes  Southeast    62592  Class 1 Obesity
# 2   52    Male  34.5         3    Yes  Northwest    60021  Class 2 Obesity
# 3   31  Female  38.1         1    Yes  Northeast    58571  Class 3 Obesity
# 4   33  Female  35.5         0    Yes  Northwest    55135  Class 2 Obesity

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'BMI', 'Children', 'Smoker', 'Region', 'Charges',
#        'Body Shape'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Age             47
# Sex              2
# BMI            274
# Children         6
# Smoker           2
# Region           4
# Charges       1284
# Body Shape       6
# dtype: int64

# %%
df.describe().apply(lambda s: s.apply(lambda x: format(x, 'f')))
# Out:
#                Age          BMI     Children       Charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663303     1.094918  13269.928999
# std      14.049960     6.098257     1.205493  12110.012755
# min      18.000000    16.000000     0.000000   1121.000000
# 25%      27.000000    26.300000     0.000000   4740.000000
# 50%      39.000000    30.400000     1.000000   9381.500000
# 75%      51.000000    34.700000     2.000000  16639.250000
# max      64.000000    53.100000     5.000000  63770.000000

# %% [markdown]
# **Alot of the data cleaning has already been done by project_functions *load_and_process* function**

# %%
df_cleaned = df

# %%
df_cleaned = df_cleaned[df_cleaned['Charges'] < 40000]
df_cleaned = df_cleaned[df_cleaned['BMI'] < 38]

# %%
sns.boxplot(x='Sex', y='Charges', data=df_cleaned)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Charges'>

# %%
df_cleaned.describe().apply(lambda s: s.apply(lambda x: format(x, 'f')))
# Out:
#                Age          BMI     Children       Charges
# count  1124.000000  1124.000000  1124.000000   1124.000000
# mean     38.339858    28.973754     1.092527  11372.500890
# std      13.843360     4.808196     1.207861   9298.648327
# min      18.000000    16.000000     0.000000   1121.000000
# 25%      26.000000    25.575000     0.000000   4514.500000
# 50%      38.000000    29.100000     1.000000   8649.000000
# 75%      50.000000    32.800000     2.000000  14221.000000
# max      64.000000    37.900000     5.000000  39983.000000

# %%
df_cleaned = df_cleaned.dropna()
df_cleaned.shape
# Out:
# (1124, 8)

# %%
corr = df_cleaned.corr()
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
df_cleaned.plot(kind='scatter', x='Age', y='Charges')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Charges'>

# %%
df_cleaned.plot(kind='scatter', x='BMI', y='Charges')
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='Charges'>

# %%
sns.pairplot(df_cleaned)

# %%
df_cleaned['Age'].plot(kind='hist', bins=25, edgecolor='white', facecolor='purple')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df_cleaned.boxplot('Charges')
# Out:
# <AxesSubplot:>
